# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px

# %%
path = r"C:\Users\USER\Desktop\Jupyter_Lab\UANL\SEM7\Mineria\MineriaUANL\P1\spotify-2023.xlsx"
data = pd.read_excel(path)
data = data.sort_values("released_year",ascending=False)

# %%
data
# Out:
#                                             track_name  \
# 0                  Seven (feat. Latto) (Explicit Ver.)
# 210                                           Abcdario
# 351                                           PERO Tï¿
# 174                                       ýýýýýýýýýýýý
# 348                                 Red Ruby Da Sleeze
# ..                                                 ...
# 459           A Holly Jolly Christmas - Single Version
# 466             Let It Snow! Let It Snow! Let It Snow!
# 460  The Christmas Song (Merry Christmas To You) - ...
# 469                                    White Christmas
# 439                                    Agudo Mï¿½ï¿½gi
#
#                                         artist(s)_name  artist_count  \
# 0                                     Latto, Jung Kook             2
# 210                              Junior H, Eden Muï¿½ï             2
# 351                                   Karol G, Quevedo             2
# ...

# %%
print(data["released_year"].min())
print(data["released_year"].max())
# Out:
# 1930
# 2023

# %%
groupYearly = data.groupby(["released_year"])["track_name"].count().reset_index()
groupYearly.sort_values("track_name",ascending=False)
# Out:
#     released_year  track_name
# 48           2022         402
# 49           2023         175
# 47           2021         119
# 46           2020          37
# 45           2019          36
# 43           2017          23
# 42           2016          18
# 39           2013          13
# 40           2014          13
# 41           2015          11
# 44           2018          10
# 37           2011          10
# 38           2012          10
# 36           2010           7
# 30           2002           6
# 28           1999           5
# 32           2004           4
# 29           2000           4
# 17           1984           4
# 8            1963           3
# 6            1958           3
# 24           1995           2
# 31           2003           2
# 35           2008           2
# 10           1970           2
# 5            1957           2
# 19           1986           2
# 18           1985           2
# 15           1982           2
# 7            1959           2
# ...

# %%
data2022 = data[data["released_year"]==2022]
data2023 = data[data["released_year"]==2023]
data2021 = data[data["released_year"]==2021]

# %%
group2022_artists = data2022.groupby(["artist(s)_name"])["track_name"].count().reset_index()
group2022_artists.sort_values("track_name",ascending=False)
# Out:
#                                         artist(s)_name  track_name
# 217                                                SZA          17
# 240                                       Taylor Swift          16
# 16                                           Bad Bunny          15
# 95                                        Harry Styles          13
# 243                                         The Weeknd          13
# ..                                                 ...         ...
# 105                          John Legend, Metro Boomin           1
# 107  Jordan Fisher, Josh Levi, Finneas O'Connell, 4...           1
# 108                                          Jung Kook           1
# 109                         Justin Bieber, Don Toliver           1
# 272                                               teto           1
#
# [273 rows x 2 columns]

# %%
group2023_artists = data2023.groupby(["artist(s)_name"])["track_name"].count().reset_index()
group2023_artists.sort_values("track_name",ascending=False)
# Out:
#                                     artist(s)_name  track_name
# 81                                   Morgan Wallen           8
# 131                                   Taylor Swift           6
# 51                                           Jimin           3
# 87                                        NewJeans           3
# 57                                         Karol G           3
# ..                                             ...         ...
# 43                                     IU, Agust D           1
# 42                                    Halsey, Suga           1
# 41                                           Gunna           1
# 40          Grupo Marca Registrada, Grupo Frontera           1
# 146  sped up nightcore, ARIZONATEARS, Lil Uzi Vert           1
#
# [147 rows x 2 columns]

# %%
group2021_artists = data2021.groupby(["artist(s)_name"])["track_name"].count().reset_index()
group2021_artists.sort_values("track_name",ascending=False)
# Out:
#                                       artist(s)_name  track_name
# 69                                    Olivia Rodrigo           6
# 20                                          Doja Cat           4
# 78                                   Sebastian Yatra           2
# 10                                     Billie Eilish           2
# 87                                        The Weeknd           2
# ..                                               ...         ...
# 34   Imagine Dragons, League of Legends, JID, Arcane           1
# 33        Imagine Dragons, League of Legends, Arcane           1
# 32                                   Imagine Dragons           1
# 31                                               IVE           1
# 102                                        Yng Lvcas           1
#
# [103 rows x 2 columns]

# %%
group2022_monthlyTracks = data2022.groupby(["released_month"])["track_name"].count().reset_index()
group2022_monthlyTracks
# Out:
#     released_month  track_name
# 0                1          37
# 1                2          28
# 2                3          27
# 3                4          30
# 4                5          75
# 5                6          29
# 6                7          26
# 7                8          19
# 8                9          20
# 9               10          37
# 10              11          26
# 11              12          48

# %%
group2023_monthlyTracks = data2023.groupby(["released_month"])["track_name"].count().reset_index()
group2023_monthlyTracks
# Out:
#    released_month  track_name
# 0               1          19
# 1               2          23
# 2               3          37
# 3               4          21
# 4               5          29
# 5               6          32
# 6               7          14

# %%
group2021_monthlyTracks = data2021.groupby(["released_month"])["track_name"].count().reset_index()
group2021_monthlyTracks
# Out:
#     released_month  track_name
# 0                1           3
# 1                3           5
# 2                4           8
# 3                5           8
# 4                6          11
# 5                7           8
# 6                8          12
# 7                9          18
# 8               10          12
# 9               11          21
# 10              12          13
